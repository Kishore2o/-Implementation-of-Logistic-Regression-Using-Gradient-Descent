# %% [markdown]
# <a href="https://colab.research.google.com/github/Kishore2o/-Implementation-of-Logistic-Regression-Using-Gradient-Descent/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
import gspread
from google.auth import default
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

worksheet = gc.open('StudentsData').sheet1
data=worksheet.get_all_values()
print(data)

StudentsData = pd.DataFrame(data[1:], columns=data[0])
StudentsData = StudentsData.astype({'INPUT':'float'})
StudentsData = StudentsData.astype({'OUTPUT':'float'})

X = StudentsData[['INPUT']].values
y = StudentsData[['OUTPUT']].values

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.30,random_state = 30)

Scaler = MinMaxScaler()
Scaler.fit(X_train)
X_train1 = Scaler.transform(X_train)

ai_model=Sequential([
    Dense(units=8,activation='relu',input_shape=[1]),
    Dense(units=9,activation='relu'),
    Dense(units=1)
])

ai_model.compile(optimizer='rmsprop',loss='mse')

ai_model.fit(X_train1,y_train,epochs=20)

loss_df = pd.DataFrame(ai_model.history.history)
loss_df.plot()

X_test1 = Scaler.transform(X_test)
ai_model.evaluate(X_test1,y_test)

X_n1 = [[30]]
X_n1_1 = Scaler.transform(X_n1)
ai_model.predict(X_n1_1)
# Out:
# [['INPUT', 'OUTPUT'], ['1', '11'], ['2', '21'], ['3', '31'], ['4', '41'], ['5', '51'], ['6', '61'], ['7', '71'], ['8', '81'], ['9', '91'], ['10', '101'], ['11', '111'], ['12', '121'], ['13', '131'], ['14', '141'], ['15', '151'], ['16', '161'], ['17', '171'], ['18', '181'], ['19', '191'], ['20', '201']]
# Epoch 1/20
# 1/1 [==============================] - 0s 332ms/step - loss: 15095.2812
# Epoch 2/20
# 1/1 [==============================] - 0s 7ms/step - loss: 15088.8418
# Epoch 3/20
# 1/1 [==============================] - 0s 7ms/step - loss: 15084.0332
# Epoch 4/20
# 1/1 [==============================] - 0s 7ms/step - loss: 15079.9326
# Epoch 5/20
# 1/1 [==============================] - 0s 6ms/step - loss: 15076.2334
# Epoch 6/20
# 1/1 [==============================] - 0s 7ms/step - loss: 15072.7949
# Epoch 7/20
# 1/1 [==============================] - 0s 6ms/step - loss: 15069.5420
# Epoch 8/20
# 1/1 [==============================] - 0s 7ms/step - loss: 15066.4219
# Epoch 9/20
# 1/1 [==============================] - 0s 7ms/step - loss: 15063.4014
# Epoch 10/20
# 1/1 [==============================] - 0s 6ms/step - loss: 15060.4619
# Epoch 11/20
# 1/1 [==============================] - 0s 6ms/step - loss: 15057.5801
# Epoch 12/20
# 1/1 [==============================] - 0s 7ms/step - loss: 15054.7490
# Epoch 13/20
# 1/1 [==============================] - 0s 6ms/step - loss: 15051.9551
# Epoch 14/20
# 1/1 [==============================] - 0s 6ms/step - loss: 15049.1895
# Epoch 15/20
# 1/1 [==============================] - 0s 6ms/step - loss: 15046.4463
# Epoch 16/20
# 1/1 [==============================] - 0s 5ms/step - loss: 15043.7236
# Epoch 17/20
# 1/1 [==============================] - 0s 6ms/step - loss: 15041.0127
# Epoch 18/20
# 1/1 [==============================] - 0s 6ms/step - loss: 15038.3105
# Epoch 19/20
# 1/1 [==============================] - 0s 5ms/step - loss: 15035.6152
# Epoch 20/20
# 1/1 [==============================] - 0s 6ms/step - loss: 15032.9229
# 1/1 [==============================] - 0s 137ms/step - loss: 12992.4580
# 1/1 [==============================] - 0s 93ms/step
# array([[1.4301096]], dtype=float32)

# %%
df.head(20)
# Out:
#     INPUT  OUTPUT
# 0     1.0    11.0
# 1     2.0    21.0
# 2     3.0    31.0
# 3     4.0    41.0
# 4     5.0    51.0
# 5     6.0    61.0
# 6     7.0    71.0
# 7     8.0    81.0
# 8     9.0    91.0
# 9    10.0   101.0
# 10   11.0   111.0
# 11   12.0   121.0
# 12   13.0   131.0
# 13   14.0   141.0
# 14   15.0   151.0
# 15   16.0   161.0
# 16   17.0   171.0
# 17   18.0   181.0
# 18   19.0   191.0
# 19   20.0   201.0
